# %%
# !pip -q install torch lightning transformers datasets scikit-learn
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 825.2/825.2 kB 12.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 30.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 829.2/829.2 kB 45.6 MB/s eta 0:00:00

# %%
from google.colab import drive
import os, sys
drive.mount('/content/drive', force_remount=True)
os.chdir('/content/drive/My Drive/School/CS7391 - LLM Research Ind. Study/FutureGPT2-public-master/workspace/FutureGPT2/src/')
os.listdir()
# Out:
# Mounted at /content/drive
# ['configs', 'scripts', 'models', 'nhrun.sh', 'data', 'notebooks', 'evals']

# %%
from google.colab import drive
import os, sys
drive.mount('/content/drive', force_remount=True)
os.chdir('/content/drive/My Drive/School/CS7391 - LLM Research Ind. Study/FutureGPT2-public-master/')
os.listdir()
# Out:
# Mounted at /content/drive
# ['workspace']

# %%
os.chdir('workspace/FutureGPT2')
os.listdir()
# Out:
# ['.gitignore', 'README.md', 'src']

# %%
from google.colab import drive
import os, sys
drive.mount('/content/drive/', force_remount=True)

os.chdir('/content/drive/')
os.listdir()
# Out:
# Mounted at /content/drive/
# ['Othercomputers',
#  'MyDrive',
#  '.shortcut-targets-by-id',
#  '.Trash-0',
#  '.Encrypted']

# %%
# make a fake /workspace and symlink your folder into it
# !mkdir -p /workspace
# !ln -s "/content/drive/My Drive/School/CS7391 - LLM Research Ind. Study/FutureGPT2-public-master/workspace/" /workspace/

# %% [markdown]
# # Testing and Implementing Wu et Al Research

# %%
import os
os.environ['HF_HOME'] = '/workspace/cache/huggingface/'

import os
os.chdir('/workspace/FutureGPT2/src/')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3464507764.py in <cell line: 0>()
#       3
#       4 import os
# ----> 5 os.chdir('/workspace/FutureGPT2/src/')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/workspace/FutureGPT2/src/'
